# %%
import pandas as pd
from pathlib import Path
import requests

# %%
# Set the path to the datasets directory
datasets_location = Path("__file__").parent / "data"
data1 = "customers.csv"
data2 = "purchases.csv"

# Check if the datasets exists
if not ((datasets_location / data1 ).exists() or (datasets_location / data2 ).exists()):
    print(f"please include both {data1} and {data2} files in the data folder.")
    exit(1)

# Load the datasets
customer_df = pd.read_csv(datasets_location / data1, delimiter=";")
purchases_df = pd.read_csv(datasets_location / data2, delimiter=";")

# %%
customer_df
# Out:
#    customer_id  title lastname   firstname  postal_code    city  \
# 0            1      2   Norris       Chuck      83600.0  Fréjus
# 1            2      1  Galante       Marie          NaN     NaN
# 2            3      2  Barbier  Christophe      75009.0   Paris
# 3            4      1      NaN         NaN          NaN     NaN
# 4            5      2   Dupont        Eric      21000.0   Dijon
#
#                       email
# 0          chuck@norris.com
# 1   marie-galante@france.fr
# 2     christophe@fake.email
# 3                       NaN
# 4  eric.dupont@bourgogne.fr

# %%
purchases_df
# Out:
#   purchase_identifier  customer_id  product_id  quantity  price currency  \
# 0                2/01            2        1221         1     10      EUR
# 1                1/01            1        4324         1     10      EUR
# 2                3/01            3       75672         1     10      USD
# 3                3/02            3        2123         1     10      EUR
# 4                2/02            2        3213         1     10      EUR
#
#          date
# 0  2017-12-31
# 1  2030-12-31
# 2  2050-12-31
# 3  2017-08-01
# 4  2030-12-31

# %%
customer_df = customer_df.assign(
    civility = lambda x: x['title'].map({1: 'Male', 2: 'Female'}).fillna(''),
    salutation = lambda x: x['title'].map({1: 'Mr', 2: 'Mrs'}).fillna(''),
)
customer_df
# Out:
#    customer_id  title lastname   firstname  postal_code    city  \
# 0            1      2   Norris       Chuck      83600.0  Fréjus
# 1            2      1  Galante       Marie          NaN     NaN
# 2            3      2  Barbier  Christophe      75009.0   Paris
# 3            4      1      NaN         NaN          NaN     NaN
# 4            5      2   Dupont        Eric      21000.0   Dijon
#
#                       email civility salutation
# 0          chuck@norris.com   Female        Mrs
# 1   marie-galante@france.fr     Male         Mr
# 2     christophe@fake.email   Female        Mrs
# 3                       NaN     Male         Mr
# 4  eric.dupont@bourgogne.fr   Female        Mrs

# %%
purchases_df = purchases_df.assign(
    currency = lambda x: x['currency'].map({'EUR': 'euro', 'USD': 'dollars'}))

# %%
joined = pd.merge(customer_df, purchases_df, on='customer_id', how='right')
joined
# Out:
#    customer_id  title lastname   firstname  postal_code    city  \
# 0            2      1  Galante       Marie          NaN     NaN
# 1            1      2   Norris       Chuck      83600.0  Fréjus
# 2            3      2  Barbier  Christophe      75009.0   Paris
# 3            3      2  Barbier  Christophe      75009.0   Paris
# 4            2      1  Galante       Marie          NaN     NaN
#
#                      email civility salutation purchase_identifier  \
# 0  marie-galante@france.fr     Male         Mr                2/01
# 1         chuck@norris.com   Female        Mrs                1/01
# 2    christophe@fake.email   Female        Mrs                3/01
# 3    christophe@fake.email   Female        Mrs                3/02
# 4  marie-galante@france.fr     Male         Mr                2/02
#
#    product_id  quantity  price currency        date
# 0        1221         1     10     euro  2017-12-31
# 1        4324         1     10     euro  2030-12-31
# 2       75672         1     10  dollars  2050-12-31
# 3        2123         1     10     euro  2017-08-01
# 4        3213         1     10     euro  2030-12-31

# %%
def purchased_objects(data):
    return data.apply(lambda x: {'product_id': x['product_id'], 'price': x['price'], 'currency': x['currency'], 'quantity': x['quantity'], 'purchased_at': x['date']},axis=1).tolist()

json = joined.groupby(['customer_id', 'salutation', 'lastname', 'firstname', 'email']).apply(purchased_objects, include_groups=False).reset_index(name='purchases')

# %%
payload = json.to_dict(orient='records')

for customer in payload:
    del customer['customer_id']

payload
# Out:
# [{'salutation': 'Mrs',
#   'lastname': 'Norris',
#   'firstname': 'Chuck',
#   'email': 'chuck@norris.com',
#   'purchases': [{'product_id': 4324,
#     'price': 10,
#     'currency': 'euro',
#     'quantity': 1,
#     'purchased_at': '2030-12-31'}]},
#  {'salutation': 'Mr',
#   'lastname': 'Galante',
#   'firstname': 'Marie',
#   'email': 'marie-galante@france.fr',
#   'purchases': [{'product_id': 1221,
#     'price': 10,
#     'currency': 'euro',
#     'quantity': 1,
#     'purchased_at': '2017-12-31'},
#    {'product_id': 3213,
#     'price': 10,
#     'currency': 'euro',
#     'quantity': 1,
#     'purchased_at': '2030-12-31'}]},
#  {'salutation': 'Mrs',
#   'lastname': 'Barbier',
#   'firstname': 'Christophe',
#   'email': 'christophe@fake.email',
#   'purchases': [{'product_id': 75672,
#     'price': 10,
#     'currency': 'dollars',
#     'quantity': 1,
#     'purchased_at': '2050-12-31'},
#    {'product_id': 2123,
#     'price': 10,
#     'currency': 'euro',
#     'quantity': 1,
#     'purchased_at': '2017-08-01'}]}]
